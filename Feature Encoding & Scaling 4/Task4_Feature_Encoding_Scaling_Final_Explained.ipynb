# %% [markdown]
# # Task 4: Feature Encoding & Scaling
# Adult Income Dataset

# %%
import pandas as pd
df = pd.read_csv("adult.csv")
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# This code loads the Adult Income dataset into a DataFrame for preprocessing.

# %%
categorical_cols = df.select_dtypes(include='object').columns
numerical_cols = df.select_dtypes(exclude='object').columns
categorical_cols, numerical_cols
# Out:
# (Index(['workclass', 'education', 'marital.status', 'occupation',
#         'relationship', 'race', 'sex', 'native.country', 'income'],
#        dtype='object'),
#  Index(['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss',
#         'hours.per.week'],
#        dtype='object'))

# %% [markdown]
# This separates categorical and numerical columns so correct preprocessing can be applied.

# %%
df.replace("?", pd.NA, inplace=True)
df.dropna(inplace=True)

# %% [markdown]
# This removes missing values to avoid errors and bias in machine learning models.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['income'] = le.fit_transform(df['income'])

# %% [markdown]
# Label Encoding converts the target variable into numeric form required by ML algorithms.

# %%
df = pd.get_dummies(df, columns=categorical_cols.drop('income'), drop_first=True)

# %% [markdown]
# One-Hot Encoding converts categorical features into binary columns without creating order.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
df.head()
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 1  3.318236 -0.529652      -0.914016           0.0      8.941294
# 3  0.904346 -0.452613      -2.798031           0.0      7.181757
# 4 -0.216389  0.826100      -0.537212           0.0      7.181757
# 5 -0.819862  0.334393      -0.914016           0.0      6.680134
# 6 -0.475020 -0.347253      -2.044425           0.0      6.680134
#
#    hours.per.week  income  workclass_Local-gov  workclass_Private  \
# 1       -2.332443       0                False               True
# 3       -0.437702       0                False               True
# 4       -0.437702       0                False               True
# 5       -0.007079       0                False               True
# 6       -0.437702       0                False               True
#
#    workclass_Self-emp-inc  ...  native.country_Nicaragua  native.country_Peru  \
# 1                   False  ...                     False                False
# 3                   False  ...                     False                False
# 4                   False  ...                     False                False
# 5                   False  ...                     False                False
# 6                   False  ...                     False                False
#
#    native.country_Philippines  native.country_Poland  \
# 1                       False                  False
# 3                       False                  False
# 4                       False                  False
# 5                       False                  False
# 6                       False                  False
#
#    native.country_Puerto-Rico  native.country_South  native.country_Taiwan  \
# 1                       False                 False                  False
# 3                       False                 False                  False
# 4                       False                 False                  False
# 5                       False                 False                  False
# 6                       False                 False                  False
#
#    native.country_Trinadad&Tobago  native.country_United-States  \
# 1                           False                          True
# 3                           False                          True
# 4                           False                          True
# 5                           False                          True
# 6                           False                          True
#
#    native.country_Vietnam
# 1                   False
# 3                   False
# 4                   False
# 5                   False
# 6                   False
#
# [5 rows x 78 columns]

# %% [markdown]
# StandardScaler scales numerical features so all values contribute equally to the model.

# %%
df.to_csv("adult_processed.csv", index=False)

# %% [markdown]
# This saves the fully preprocessed dataset for direct use in machine learning models.
